# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <img src="6.png">

# %%
df = pd.read_csv('Auto.csv')
df
# Out:
#       mpg  weight
# 0    18.0    3504
# 1    15.0    3693
# 2    18.0    3436
# 3    16.0    3433
# 4    17.0    3449
# ..    ...     ...
# 295  25.4    3530
# 296  23.0    3900
# 297  27.2    3190
# 298  23.9    3420
# 299  34.2    2200
#
# [300 rows x 2 columns]

# %%
'''
mpg - mileage
weight - weight of the vehicle
'''
# Out:
# '\nmpg - mileage\nweight - weight of the vehicle\n'

# %%
x = df['weight']
y = df['mpg']

# %%
plt.scatter(x,y)
plt.title('Mileage vs Weight of Vehicle')
plt.xlabel('weight')
plt.ylabel('mpg')
plt.show()

# %%
df.corr()
# Out:
#              mpg    weight
# mpg     1.000000 -0.878281
# weight -0.878281  1.000000

# %%
'''
Analysis

1) r value = -0.87
2) mpg and weight are inversely proportional
3) Strong negative correlation
'''
# Out:
# '\nAnalysis\n\n1) r value = -0.87\n2) mpg and weight are inversely proportional\n3) Strong negative correlation\n'

# %% [markdown]
# <img src="4.png">

# %% [markdown]
# <img src="5.png">

# %% [markdown]
# ### Manual calculation of correlation coefficient (r)

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(x,y)
print('Pearson Correlation:',corr)
# Out:
# Pearson Correlation: -0.8782814536196801
