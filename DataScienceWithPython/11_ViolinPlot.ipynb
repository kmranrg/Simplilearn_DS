# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('gapminder_full.csv')
data
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
country = data.country
year = data.year
population = data.population
continent = data.continent
life_exp = data.life_exp
gdp_cap = data.gdp_cap

# %%
sns.violinplot(x=life_exp)
plt.show()

# %%
sns.violinplot(x=continent, y=life_exp)
plt.show()

# %%
'''
Violin plot adds density to the box plot
'''
# Out:
# '\nViolin plot adds density to the box plot\n'

# %%
'''
Limitation of Violin Plot

1) It does not tell the frequency of the dataset
'''
# Out:
# '\nLimitation of Violin Plot\n\n1) It does not tell the frequency of the dataset\n'

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(x=continent, y=life_exp)
plt.show()
# Out:
# /Users/kan/.local/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 25.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/kan/.local/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 21.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
'''
Swarm plot shows the frequency of dataset
'''
# Out:
# '\nSwarm plot shows the frequency of dataset\n'

# %%
plt.figure(figsize=(10,6))
sns.violinplot(x=continent, y=life_exp)
sns.swarmplot(x=continent, y=life_exp)
plt.show()
# Out:
# /Users/kan/.local/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 32.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/kan/.local/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 29.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/kan/.local/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 6.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
