# %% [markdown]
# # <center>Feature Engineering</center>

# %%
#In this step, we are making the data ready to use for modelling.

# %%
'''
Y -- X
Dependent variable - Independent variable
Effect - Cause
Output - Input
'''
# Out:
# '\nY -- X\nDependent variable - Independent variable\nEffect - Cause\nOutput - Input\n'

# %%
'''
mileage = speed, weight, road conditions, fuel conditions, etc.
y       =   x1,    x2,        x3,           x4
'''
# Out:
# '\nmileage = speed, weight, road conditions, fuel conditions, etc.\ny       =   x1,    x2,        x3,           x4\n'

# %%
import pandas as pd

# %%
df = pd.read_csv('MLR_car_data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
# In above dataset, Selling_Price is Y (Dependent variable), the rest are x1, x2, x3, etc.

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isna().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
df_required = df.drop('Car_Name', axis=1) # we are removing the Car_Name feature, as it's not required in predicting the Selling_Price (told by Domain Expert)
df_required
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
# adding the present year feature in the dataset
df_required['Present_Year'] = 2023

# %%
df_required
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Present_Year
# 0         Manual      0          2023
# ...

# %%
df_required['Age_Year'] = df_required['Present_Year'] - df_required['Year']
df_required
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Present_Year  Age_Year
# ...

# %%
# as now we have the age of car, so now 'Year' & 'Present_Year' features are not required
df_required.drop(['Year','Present_Year'], axis=1, inplace=True)
df_required
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  Age_Year
# 0         Manual      0         9
# 1         Manual      0        10
# 2         Manual      0         6
# ...

# %%
df_required.dtypes
# Out:
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type         object
# Seller_Type       object
# Transmission      object
# Owner              int64
# Age_Year           int64
# dtype: object

# %%
# conversion of object data types to integers
df_required = pd.get_dummies(df_required)
df_required
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Age_Year  Fuel_Type_CNG  \
# 0             3.35           5.59       27000      0         9              0
# 1             4.75           9.54       43000      0        10              0
# 2             7.25           9.85        6900      0         6              0
# 3             2.85           4.15        5200      0        12              0
# 4             4.60           6.87       42450      0         9              0
# ..             ...            ...         ...    ...       ...            ...
# 296           9.50          11.60       33988      0         7              0
# 297           4.00           5.90       60000      0         8              0
# 298           3.35          11.00       87934      0        14              0
# 299          11.50          12.50        9000      0         6              0
# 300           5.30           5.90        5464      0         7              0
#
# ...

# %% [markdown]
# ## Multi Collinearity Test

# %%
'''
This test is just for the features not the output (y) so we will the y column
'''
# Out:
# '\nThis test is just for the features not the output (y) so we will the y column\n'

# %%
df_required_x = df_required.drop('Selling_Price',axis=1)
df_required_x
# Out:
#      Present_Price  Kms_Driven  Owner  Age_Year  Fuel_Type_CNG  \
# 0             5.59       27000      0         9              0
# 1             9.54       43000      0        10              0
# 2             9.85        6900      0         6              0
# 3             4.15        5200      0        12              0
# 4             6.87       42450      0         9              0
# ..             ...         ...    ...       ...            ...
# 296          11.60       33988      0         7              0
# 297           5.90       60000      0         8              0
# 298          11.00       87934      0        14              0
# 299          12.50        9000      0         6              0
# 300           5.90        5464      0         7              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# 0                   0                 1                   1
# 1                   1                 0                   1
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_required_x.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df_required_x.corr() # it will print above values in tabular form
# Out:
#                         Present_Price  Kms_Driven     Owner  Age_Year  \
# Present_Price                1.000000    0.203647  0.008057  0.047584
# Kms_Driven                   0.203647    1.000000  0.089216  0.524342
# Owner                        0.008057    0.089216  1.000000  0.182104
# Age_Year                     0.047584    0.524342  0.182104  1.000000
# Fuel_Type_CNG               -0.011500    0.012223 -0.014272  0.017790
# Fuel_Type_Diesel             0.473306    0.172515 -0.053469 -0.064315
# Fuel_Type_Petrol            -0.465244   -0.172874  0.055687  0.059959
# Seller_Type_Dealer           0.512030    0.101419 -0.124269 -0.039896
# Seller_Type_Individual      -0.512030   -0.101419  0.124269  0.039896
# Transmission_Automatic       0.348715    0.162510  0.050316  0.000394
# Transmission_Manual         -0.348715   -0.162510 -0.050316 -0.000394
#
#                         Fuel_Type_CNG  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# ...

# %%
'''
In heatmap graph:

1) Light Shade - strong positive correlation
2) Dark Shade - strong negative correlation
3) All values in each cell is r-value
'''
# Out:
# '\nIn heatmap graph:\n\n1) Light Shade - strong positive correlation\n2) Dark Shade - strong negative correlation\n3) All values in each cell is r-value\n'

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_required_x.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>
